# %%
# Author: Gergely Zahoranszky-Kohalmi, PhD
#
# Email: gergely.zahoranszky-kohalmi@nih.gov
#
# Organization: National Center for Advancing Translational Sciences
#

# %%
# environment: routesim

import pandas as pd

import os

import requests
import json

import rxnutils
from rxnutils import chem
from rxnutils.chem import utils
from rxnutils.chem.utils import remove_atom_mapping

# %%
FNAME_IN_EVIDENCE_ALL = []



DIR_IN_EVIDENCE = '../data/output/routes_inv/rxns/'
DIR_OUT_EVIDENCE = '../data/output/routes_inv/mapped_rxns/'

DO_SANITIZE = False
DO_CANONICALIZE = False

URL_RXNMAPPER = 'http://localhost:8002/syngps-app/api/v1/reaction_utils/atommap'

# %%
# Functions

def rxsmiles2mappedrxsmiles (rxsmiles):
    """
        Search depths: maximal number of reactions steps to explore.
    """
    
    # Base URL for your API

    rxsmiles = rxsmiles.split(' ')[0].strip()   # This returns the extension-free RXSMILES

    print (f'[*] Original RXSMILES: {rxsmiles} .')

    contituents = []
    contituents = rxsmiles.split('>')

    reactants = contituents[0].strip().split('.')
    reagents = contituents[1].strip().split('.')
    products = contituents[2].strip().split('.')





    
    no_map_reactants = []
    no_map_reagents = []
    no_map_products = []
    
    for smi in reactants:
        nomap_smi = remove_atom_mapping(smi, is_smarts = False, sanitize = DO_SANITIZE, canonical = DO_CANONICALIZE)
        no_map_reactants.append(nomap_smi)
    
    if len (reagents) > 0:
        for smi in reagents:
            nomap_smi = remove_atom_mapping(smi, is_smarts = False, sanitize = DO_SANITIZE, canonical = DO_CANONICALIZE)
            no_map_reagents.append(nomap_smi)

    for smi in products:
        nomap_smi = remove_atom_mapping(smi, is_smarts = False, sanitize = DO_SANITIZE, canonical = DO_CANONICALIZE)
        no_map_products.append(nomap_smi)
    
    reactants = ".".join(no_map_reactants)
    reagents = ".".join(no_map_reagents)
    products = ".".join(no_map_products)

    nomap_rxsmiles = ">".join([reactants, reagents, products])

    print (f'[*] Atom-mapping removed RXSMILES: {nomap_rxsmiles}')
    
    try:
        # Step 1: Make POST request to /api/test
        print("Atommapping reaction ...")
        
        # Optional: Include data in the first request if needed




        rxnmapper_payload = {
            "smiles": nomap_rxsmiles
        }



        # synth_route_search_payload = {
        #     "target_molecule_inchikey": target_molecule_inchikey,
        #     "reaction_steps": search_depth,
        #     "query_type": search_type,
        #     "leaves_as_sm": leaves_as_sm,
        #     "include_availability_info": False,
        #     "annotate_reactions": False,
        #     "graph_backend": "memgraph",
        #     "top_n_routes": top_n,
        #     "include_route_candidates": False,
        #     "include_combination_graphs": False
        # }
        
        response1 = requests.post(
            url = URL_RXNMAPPER,
            json = rxnmapper_payload,
            headers={'Content-Type': 'application/json',
                     'accept': 'application/json'})
        
        # Check if the request was successful
        #response1.raise_for_status()
        
        # Get JSON data from response
        received_data = response1.json()
        #print(f"Received data: {json.dumps(received_data, indent=2)}")


        return (received_data['mapped_rxsmiles'])
    
    except requests.exceptions.RequestException as e:
    
        print(f"Error occurred: {e}")

        return (None)


def annotate_routes_by_atommapping (fname_in, fname_out):
    df = pd.read_csv (fname_in, sep = '\t')

    print (df)

    df['real_mapped_rxsmiles'] = df.apply(lambda x: rxsmiles2mappedrxsmiles (x['rxsmiles']), axis = 1)

    df = df[['tm_inchikey', 'rxsmiles', 'route_index', 'real_mapped_rxsmiles']].copy()

    df = df.rename (columns = {
        'real_mapped_rxsmiles': 'mapped_reaction_smiles'
    })

    df.to_csv(fname_out, sep = '\t', index = False)

# %%
# Ensure DIR_OUT_EVIDENCE exists
if not os.path.exists(DIR_OUT_EVIDENCE):
    os.makedirs(DIR_OUT_EVIDENCE)

search_obj = os.scandir(DIR_IN_EVIDENCE)

for dir_item in search_obj:
    if dir_item.is_file():
        
        FNAME_IN_EVIDENCE_ALL.append(DIR_IN_EVIDENCE + dir_item.name)

print(FNAME_IN_EVIDENCE_ALL)

idx = 1

for fname in FNAME_IN_EVIDENCE_ALL:
    fname_out = fname.split('/')[-1]                    \
                                    .strip()            \
                                    .split('.')[0]      \
                                    .strip()          \
                                    + '_evidence_mapped_rxn.tsv'
    
    fname_out = DIR_OUT_EVIDENCE + fname_out
    
    print (f'[*] Processing route nr. {idx} of {len(FNAME_IN_EVIDENCE_ALL)} ..')
    
    idx += 1

    try:
        annotate_routes_by_atommapping (fname, fname_out)
    
    except:
        print (f'[W] Some of the reactions could not be atommapped in input file: {fname} .')

    print (f'[*] .. done.')
# Out:
# ['../data/output/routes_inv/rxns/IHXNMNXXLBANRT-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/HLXQFVUPAUJHJI-VIFPVBQESA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/GZYNUOMXGGSXMI-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/QIXXLCJOJGHZJB-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/PBLNHHSDYFYZNC-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/VTJXLVGZNOINAD-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/WEEVXEKXCIBZMB-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/NHVUPUQLKWAQMU-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/KJDKPNUDCPAPKM-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/MGPKTKXUWSVAMY-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/HDQNXIOVYVAKBX-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/NVTKJBXOBFRPLQ-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/BIAAFFAHROMCHN-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/MVZQNMZKBOUDCI-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/CYSOFAOLQAYKGU-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/IQNMCFJVBQJVNL-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/DLLGXKPWXXZQFL-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/QHQSWYIJDFMBNE-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/OPYBJNYVSLHSQI-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/FZFXOEUVGCHONA-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/WUFUURSWOJROKY-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/IXZILUICVMZFAS-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/LYPSYIWSZQVHAB-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/FNMOSYNODGOFRC-AWEZNQCLSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/OHWDZAOJWZFPOI-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/SMFTYTRLFIZIPU-NGZATLCBSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/UZCLUOWLQYOFSZ-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/BVKGNQRDVFGNIW-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/UBKOYAUKDZMQDZ-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/NMNZWFGWFXMILV-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/VLYBAPCPKDLKOF-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/DJRUWESABPZMRB-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/JACPDLJUQLKABC-UHFFFAOYSA-N_evidence_based_route_rxn.tsv', '../data/output/routes_inv/rxns/ILMBNGXIGGVYQY-UHFFFAOYSA-N_evidence_based_route_rxn.tsv']
# [*] Processing route nr. 1 of 34 ..
#                    tm_inchikey  \
# 0  IHXNMNXXLBANRT-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  
# [*] Atom-mapping removed RXSMILES: N1C=C(C2=NC=NC3=C2C=CN3COCC[Si](C)(C)C)C=N1.C1(C=CC#N)CCCC1>C1CCN2C(=NCCC2)CC1.C(#N)C.ClCCl>C1(C(N2C=C(C3=NC=NC4=C3C=CN4COCC[Si](C)(C)C)C=N2)CC#N)CCCC1
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 19 of 34 ..
#                    tm_inchikey  \
# 0  OPYBJNYVSLHSQI-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  O1C2C(=CC=CC=2)/C(=[N:11]/[OH:12])/CC1.[CH2:13...            1
# [*] Original RXSMILES: O1C2C(=CC=CC=2)/C(=[N:11]/[OH:12])/CC1.[CH2:13]([CH:15]1[CH2:23][C:22]2[C:17](=[CH:18][CH:19]=[CH:20][CH:21]=2)[C:16]1=O)[CH3:14]>>[CH2:13]([CH:15]1[CH2:23][C:22]2[C:17](=[CH:18][CH:19]=[CH:20][CH:21]=2)[C:16]1=[N:11][OH:12])[CH3:14] .
# [*] Atom-mapping removed RXSMILES: O1C2=CC=CC=C2/C(=N/O)CC1.C(C1CC2=CC=CC=C2C1=O)C>>C(C1CC2=CC=CC=C2C1=NO)C
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 20 of 34 ..
#                    tm_inchikey  \
# 0  FZFXOEUVGCHONA-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  [Br:5][C:6]1[CH:11]=[CH:10][C:9]([C:12]2[CH:17...            1
# [*] Original RXSMILES: [Br:5][C:6]1[CH:11]=[CH:10][C:9]([C:12]2[CH:17]=[CH:16][CH:15]=[CH:14][CH:13]=2)=[C:8]([F:18])[CH:7]=1.[C:19](Cl)(=[O:21])[CH3:20]>ClC(Cl)C(Cl)Cl.[Al+3].[Cl-].[Cl-].[Cl-]>[Br:5][C:6]1[CH:11]=[CH:10][C:9]([C:12]2[CH:17]=[CH:16][C:15]([C:19](=[O:21])[CH3:20])=[CH:14][CH:13]=2)=[C:8]([F:18])[CH:7]=1 .
# [*] Atom-mapping removed RXSMILES: BrC1=CC(F)=C(C2=CC=CC=C2)C=C1.C(Cl)(=O)C>ClC(Cl)C(Cl)Cl.[Al+3].[Cl-].[Cl-].[Cl-]>BrC1=CC(F)=C(C2=CC=C(C(=O)C)C=C2)C=C1
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 21 of 34 ..
#                    tm_inchikey  \
# 0  WUFUURSWOJROKY-UHFFFAOYSA-N
# 1  WUFUURSWOJROKY-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  [OH:1][C:2]1[CH:10]=[C:9]([I:11])[CH:8]=[CH:7]...            2
# 1  [OH:1][C:2]1[CH:10]=[C:9]([I:11])[CH:8]=[CH:7]...            3
# [*] Original RXSMILES: [OH:1][C:2]1[CH:10]=[C:9]([I:11])[CH:8]=[CH:7][C:3]=1[C:4]([OH:6])=[O:5].[CH3:12][Si](C=[N+]=[N-])(C)C>C1COCC1.CO>[CH3:12][O:5][C:4](=[O:6])[C:3]1[CH:7]=[CH:8][C:9]([I:11])=[CH:10][C:2]=1[OH:1] .
UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  [C:1]1([CH2:7][S:8](Cl)(=[O:10])=[O:9])[CH:6]=...            1
# [*] Original RXSMILES: [C:1]1([CH2:7][S:8](Cl)(=[O:10])=[O:9])[CH:6]=[CH:5][CH:4]=[CH:3][CH:2]=1.Br.[Br:13][CH2:14][CH2:15][CH2:16][NH2:17]>CCN(CC)CC.C1COCC1>[Br:13][CH2:14][CH2:15][CH2:16][NH:17][S:8]([CH2:7][C:1]1[CH:6]=[CH:5][CH:4]=[CH:3][CH:2]=1)(=[O:10])=[O:9] .
# [*] Atom-mapping removed RXSMILES: C1(CS(Cl)(=O)=O)=CC=CC=C1.Br.BrCCCN>CCN(CC)CC.C1COCC1>BrCCCNS(CC1=CC=CC=C1)(=O)=O
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 32 of 34 ..
#                    tm_inchikey  \
# 0  DJRUWESABPZMRB-UHFFFAOYSA-N
# 1  DJRUWESABPZMRB-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  Br[C:2]1[CH:8]=[CH:7][C:6]([C:9]([F:12])([F:11...            3
# 1  Br[C:9]1[CH:14]=[CH:13][C:12]([C:15]([F:18])([...            4
# [*] Original RXSMILES: Br[C:2]1[CH:8]=[CH:7][C:6]([C:9]([F:12])([F:11])[F:10])=[CH:5][C:3]=1[NH2:4].C(O[C:16]([S:18][K])=[S:17])C>CN(C)C=O.O.Cl>[F:10][C:9]([F:12])([F:11])[C:6]1[CH:7]=[CH:8][C:2]2[S:17][C:16]([SH:18])=[N:4][C:3]=2[CH:5]=1 .
# [*] Atom-mapping removed RXSMILES: BrC1=C(N)C=C(C(F)(F)F)C=C1.C(OC(S[K])=S)C>CN(C)C=O.O.Cl>FC(F)(F)C1=CC2=C(C=C1)SC(S)=N2
# Atommapping reaction ...
# [*] Original RXSMILES: Br[C:9]1[CH:14]=[CH:13][C:12]([C:15]([F:18])([F:17])[F:16])=[CH:11][C:10]=1[NH2:19].C(O[C:4]([SH:6])=[S:5])C>CN(C)C=O.[K].Cl>[SH:6][C:4]1[S:5][C:9]2[CH:14]=[CH:13][C:12]([C:15]([F:16])([F:18])[F:17])=[CH:11][C:10]=2[N:19]=1 .
# [*] Atom-mapping removed RXSMILES: BrC1=C(N)C=C(C(F)(F)F)C=C1.C(OC(S)=S)C>CN(C)C=O.[K].Cl>SC1=NC2=C(S1)C=CC(C(F)(F)F)=C2
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 33 of 34 ..
#                    tm_inchikey  \
# 0  JACPDLJUQLKABC-UHFFFAOYSA-N
# 1  JACPDLJUQLKABC-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  [NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([OH:8])...            1
# 1  [NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([OH:8])...            2
# [*] Original RXSMILES: [NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([OH:8])=[O:7])=[CH:4][N:3]=1.[CH3:11]O>CC#N.C(Cl)Cl.CC>[NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([O:8][CH3:11])=[O:7])=[CH:4][N:3]=1 .
# [*] Atom-mapping removed RXSMILES: NC1=NC=C(C(O)=O)C=C1.CO>CC#N.C(Cl)Cl.CC>NC1=NC=C(C(OC)=O)C=C1
# Atommapping reaction ...
# [*] Original RXSMILES: [NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([OH:8])=[O:7])=[CH:4][N:3]=1.[CH3:11][Si](C=[N+]=[N-])(C)C>CC#N.C(Cl)Cl.CO>[NH2:1][C:2]1[CH:10]=[CH:9][C:5]([C:6]([O:8][CH3:11])=[O:7])=[CH:4][N:3]=1 .
# [*] Atom-mapping removed RXSMILES: NC1=NC=C(C(O)=O)C=C1.C[Si](C=[N+]=[N-])(C)C>CC#N.C(Cl)Cl.CO>NC1=NC=C(C(OC)=O)C=C1
# Atommapping reaction ...
# [*] .. done.
# [*] Processing route nr. 34 of 34 ..
#                    tm_inchikey  \
# 0  ILMBNGXIGGVYQY-UHFFFAOYSA-N
# 1  ILMBNGXIGGVYQY-UHFFFAOYSA-N
#
#                                             rxsmiles  route_index
# 0  [Cl:1][C:2]1[CH:3]=[C:4]([OH:12])[CH:5]=[N:6][...            1
# 1  [Cl:1][C:2]1[C:3]([O:17][CH:18]([CH3:20])[CH3:...            1
# [*] Original RXSMILES: [Cl:1][C:2]1[CH:3]=[C:4]([OH:12])[CH:5]=[N:6][C:7]=1[O:8][CH:9]([CH3:11])[CH3:10].[F:13][C:14]1[CH:22]=[C:21](F)[C:20]([F:24])=[CH:19][C:15]=1[C:16]([OH:18])=[O:17]>CS(C)=O.Cl>[Cl:1][C:2]1[CH:3]=[C:4]([O:12][C:21]2[C:20]([F:24])=[CH:19][C:15]([C:16]([OH:18])=[O:17])=[C:14]([F:13])[CH:22]=2)[CH:5]=[N:6][C:7]=1[O:8][CH:9]([CH3:10])[CH3:11] .
# [*] Atom-mapping removed RXSMILES: ClC1=C(OC(C)C)N=CC(O)=C1.FC1=C(C(O)=O)C=C(F)C(F)=C1>CS(C)=O.Cl>ClC1=C(OC(C)C)N=CC(OC2=CC(F)=C(C(O)=O)C=C2F)=C1
# Atommapping reaction ...
# [*] Original RXSMILES: [Cl:1][C:2]1[C:3]([O:17][CH:18]([CH3:20])[CH3:19])=[N:4][CH:5]=[C:6](B2OC(C)(C)C(C)(C)O2)[CH:7]=1.C(OO)(=[O:24])C>CCCCCCC.C(OC(=O)C)C.C(O)(=O)C.O>[Cl:1][C:2]1[CH:7]=[C:6]([OH:24])[CH:5]=[N:4][C:3]=1[O:17][CH:18]([CH3:20])[CH3:19] .
# [*] Atom-mapping removed RXSMILES: ClC1=CC(B2OC(C)(C)C(C)(C)O2)=CN=C1OC(C)C.C(OO)(=O)C>CCCCCCC.C(OC(=O)C)C.C(O)(=O)C.O>ClC1=C(OC(C)C)N=CC(O)=C1
# Atommapping reaction ...
# [*] .. done.

# %%
print ('[Done.]')
# Out:
# [Done.]

# %%
# References:

# Ref: https://github.com/rxn4chemistry/rxnmapper
#
